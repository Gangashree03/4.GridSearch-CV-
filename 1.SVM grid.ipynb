# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset['charges']

# %%
dependent
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid = {'kernel':['rbf','poly','sigmoid','linear'],'C':[1,10,50,100,200]}
grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3,n_jobs=-1)
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [1, 10, 50, 100, 200],
#                          'kernel': ['rbf', 'poly', 'sigmoid', 'linear']},
#              verbose=3)

# %%
re=grid.cv_results_
grid_predictions = grid.predict(x_test)
from sklearn.metrics import r2_score
r_score=r2_score(y_test,grid_predictions)
print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'C': 200, 'kernel': 'linear'}: 0.5950448084397433

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.135353      0.038957         0.037503        0.007658       1
# 1        0.085275      0.007367         0.011922        0.006145       1
# 2        0.130794      0.014063         0.031426        0.009889       1
# 3        0.109378      0.013978         0.016112        0.000592       1
# 4        0.100278      0.007797         0.040630        0.007654      10
# 5        0.080353      0.003523         0.015704        0.000150      10
# 6        0.120907      0.010199         0.031253        0.000003      10
# 7        0.107954      0.007824         0.015626        0.000002      10
# 8        0.092580      0.002799         0.041127        0.008077      50
# 9        0.094645      0.010294         0.012835        0.005211      50
# 10       0.115801      0.007525         0.031252        0.009883      50
# 11       0.158361      0.011712         0.012502        0.006251      50
# 12       0.097515      0.006962         0.037678        0.007519     100
# 13       0.090630      0.006252         0.015627        0.000002     100
# 14       0.130126      0.008079         0.028217        0.006068     100
# 15       0.227576      0.044005         0.014134        0.002992     100
# 16       0.098203      0.015150         0.043761        0.006256     200
# 17       0.096756      0.001755         0.019611        0.006694     200
# 18       0.122176      0.006413         0.020374        0.006282     200
# 19       0.341810      0.073938         0.015730        0.000196     200
#
#    param_kernel                           params  split0_test_score  \
# 0           rbf        {'C': 1, 'kernel': 'rbf'}          -0.041843
# 1          poly       {'C': 1, 'kernel': 'poly'}          -0.043786
# 2       sigmoid    {'C': 1, 'kernel': 'sigmoid'}          -0.041661
# 3        linear     {'C': 1, 'kernel': 'linear'}          -0.198935
# 4           rbf       {'C': 10, 'kernel': 'rbf'}          -0.045477
# 5          poly      {'C': 10, 'kernel': 'poly'}          -0.134216
# 6       sigmoid   {'C': 10, 'kernel': 'sigmoid'}          -0.042877
# 7        linear    {'C': 10, 'kernel': 'linear'}          -0.099849
# 8           rbf       {'C': 50, 'kernel': 'rbf'}          -0.119173
# 9          poly      {'C': 50, 'kernel': 'poly'}          -0.174414
# 10      sigmoid   {'C': 50, 'kernel': 'sigmoid'}          -0.049151
# 11       linear    {'C': 50, 'kernel': 'linear'}           0.275861
# 12          rbf      {'C': 100, 'kernel': 'rbf'}          -0.158546
# 13         poly     {'C': 100, 'kernel': 'poly'}          -0.176499
# 14      sigmoid  {'C': 100, 'kernel': 'sigmoid'}          -0.059561
# 15       linear   {'C': 100, 'kernel': 'linear'}           0.477795
# 16          rbf      {'C': 200, 'kernel': 'rbf'}          -0.182586
# 17         poly     {'C': 200, 'kernel': 'poly'}          -0.179850
# 18      sigmoid  {'C': 200, 'kernel': 'sigmoid'}          -0.088975
# 19       linear   {'C': 200, 'kernel': 'linear'}           0.532573
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0           -0.035206          -0.148244          -0.140044
# 1           -0.002226          -0.134941          -0.142337
# 2           -0.038119          -0.149384          -0.138544
# 3            0.026229          -0.236356          -0.247440
# 4           -0.013336          -0.151791          -0.151967
# 5            0.026782          -0.212979          -0.237453
# 6           -0.039512          -0.150154          -0.138492
# 7            0.109498          -0.136196          -0.141381
# 8            0.012149          -0.214514          -0.221544
# 9            0.030427          -0.229946          -0.266444
# 10          -0.048913          -0.151316          -0.145925
# 11           0.419812           0.224108           0.241250
# 12           0.013775          -0.243127          -0.254520
# 13           0.036989          -0.230291          -0.265222
# 14          -0.063480          -0.155368          -0.152757
# 15           0.582292           0.432079           0.458983
# 16           0.013609          -0.253762          -0.268301
# 17           0.041748          -0.225064          -0.261232
# 18          -0.100252          -0.184964          -0.171241
# 19           0.629972           0.497787           0.539239
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.141968        -0.101461        0.051502                7
# 1           -0.131036        -0.090865        0.057060                5
# 2           -0.142370        -0.102016        0.050856                8
# 3           -0.157780        -0.162857        0.099637               19
# 4           -0.139448        -0.100404        0.059028                6
# 5           -0.159582        -0.143490        0.092731               13
# 6           -0.143396        -0.102886        0.050518                9
# 7           -0.075432        -0.068672        0.092313                4
# 8           -0.164301        -0.141477        0.085281               12
# 9           -0.169021        -0.161880        0.102720               18
# 10          -0.146513        -0.108364        0.048480               10
# 11           0.249917         0.282190        0.070811                3
# 12          -0.166782        -0.161840        0.095993               17
# 13          -0.171039        -0.161212        0.105075               16
# 14          -0.160115        -0.118256        0.046401               11
# 15           0.439511         0.478132        0.054459                2
# 16          -0.174439        -0.173096        0.100520               20
# 17          -0.168346        -0.158549        0.105486               15
# 18          -0.181512        -0.145389        0.041855               14
# 19           0.500963         0.540107        0.047868                1

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
Children_input=float(input("Children:"))
sex_male_input=int(input("sex male 0 or 1:"))
smoker_yes_input=int(input("smoker yes 0 or 1:"))
# Out:
# Age:21
# BMI:30
# Children:2
# sex male 0 or 1:0
# smoker yes 0 or 1:0

# %%
future_prediction=grid.predict([[age_input,bmi_input,Children_input,sex_male_input,smoker_yes_input]])
print("future_prediction={}".format(future_prediction))
# Out:
# C:\Users\ELCOT\Anaconda3\lib\site-packages\sklearn\base.py:442: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   "X does not have valid feature names, but"
# future_prediction=[2839.33100049]
